# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
a=np.array([[1,2,6],[5,8,1],[7,6,1]])

# %%
a
# Out:
# array([[1, 2, 6],
#        [5, 8, 1],
#        [7, 6, 1]])

# %%
#line plot
plt.plot(a)
plt.show()
